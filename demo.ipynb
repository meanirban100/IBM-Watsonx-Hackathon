# %%
# !py -m pip install streamlit_jupyter
# Out:
# Collecting streamlit_jupyter
#   Downloading streamlit_jupyter-0.2.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting fastcore (from streamlit_jupyter)
#   Downloading fastcore-1.7.8-py3-none-any.whl.metadata (3.5 kB)
# Collecting ipywidgets==7.7.2 (from streamlit_jupyter)
#   Downloading ipywidgets-7.7.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting jupyter (from streamlit_jupyter)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting stqdm (from streamlit_jupyter)
#   Downloading stqdm-0.0.5-py3-none-any.whl.metadata (3.0 kB)
# Collecting streamlit>=1.19 (from streamlit_jupyter)
#   Using cached streamlit-1.38.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit_jupyter) (0.9.0)
# Requirement already satisfied: tqdm in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit_jupyter) (4.66.5)
# Collecting ipykernel>=4.5.1 (from ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython-genutils~=0.2.0 (from ipywidgets==7.7.2->streamlit_jupyter)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting traitlets>=4.3.1 (from ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting widgetsnbextension~=3.6.0 (from ipywidgets==7.7.2->streamlit_jupyter)
#   Downloading widgetsnbextension-3.6.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting ipython>=4.0.0 (from ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached ipython-8.27.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets==7.7.2->streamlit_jupyter)
#   Downloading jupyterlab_widgets-1.1.10-py3-none-any.whl.metadata (3.7 kB)
# Collecting altair<6,>=4.0 (from streamlit>=1.19->streamlit_jupyter)
#   Using cached altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit>=1.19->streamlit_jupyter)
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (4.25.4)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (13.8.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (3.1.43)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit>=1.19->streamlit_jupyter)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting tornado<7,>=6.0.3 (from streamlit>=1.19->streamlit_jupyter)
#   Using cached tornado-6.4.1-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
# Collecting watchdog<5,>=2.1.5 (from streamlit>=1.19->streamlit_jupyter)
#   Using cached watchdog-4.0.2-py3-none-win_amd64.whl.metadata (38 kB)
# Collecting notebook (from jupyter->streamlit_jupyter)
#   Downloading notebook-7.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter->streamlit_jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter->streamlit_jupyter)
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab (from jupyter->streamlit_jupyter)
#   Using cached jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: colorama in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from tqdm->streamlit_jupyter) (0.4.6)
# Requirement already satisfied: jinja2 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (4.23.0)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter)
#   Using cached narwhals-1.8.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit_jupyter) (4.0.11)
# Collecting comm>=0.1.1 (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached debugpy-1.8.5-cp312-cp312-win_amd64.whl.metadata (1.1 kB)
# Collecting jupyter-client>=6.1.12 (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter)
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: nest-asyncio in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (6.0.0)
# Collecting pyzmq>=24 (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached pyzmq-26.2.0-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# Requirement already satisfied: decorator in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (5.1.1)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (2.18.0)
# Collecting stack-data (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit_jupyter) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit_jupyter) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit_jupyter) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit_jupyter) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit_jupyter) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit_jupyter) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit_jupyter) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.19->streamlit_jupyter) (3.0.0)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter->streamlit_jupyter)
#   Using cached jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook->jupyter->streamlit_jupyter)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook->jupyter->streamlit_jupyter)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->streamlit_jupyter)
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->streamlit_jupyter) (0.27.0)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->streamlit_jupyter)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->streamlit_jupyter) (74.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->streamlit_jupyter) (4.12.3)
# Collecting bleach!=5.0.0 (from nbconvert->jupyter->streamlit_jupyter)
#   Using cached bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: defusedxml in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->streamlit_jupyter) (0.7.1)
# Collecting jupyterlab-pygments (from nbconvert->jupyter->streamlit_jupyter)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->streamlit_jupyter) (2.1.5)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter->streamlit_jupyter)
#   Using cached mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter->streamlit_jupyter)
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter->streamlit_jupyter)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter->streamlit_jupyter)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert->jupyter->streamlit_jupyter)
#   Using cached tinycss2-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->streamlit_jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->streamlit_jupyter) (0.5.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit_jupyter) (5.0.1)
# Requirement already satisfied: anyio in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->streamlit_jupyter) (4.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->streamlit_jupyter) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->streamlit_jupyter) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->streamlit_jupyter) (0.14.0)
# Collecting parso<0.9.0,>=0.8.3 (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (306)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: overrides>=5.0 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter) (0.20.0)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached pywinpty-2.0.13-cp312-none-win_amd64.whl.metadata (5.2 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter) (1.8.0)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->streamlit_jupyter)
#   Using cached babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->streamlit_jupyter)
#   Using cached json5-0.9.25-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.19->streamlit_jupyter) (0.1.2)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert->jupyter->streamlit_jupyter)
#   Using cached fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: wcwidth in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->streamlit_jupyter) (2.6)
# Collecting executing>=1.2.0 (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pure-eval (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter) (6.0.2)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached webcolors-24.8.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\61092657\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter) (2.22)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit_jupyter)
#   Using cached types_python_dateutil-2.9.0.20240906-py3-none-any.whl.metadata (1.9 kB)
# Downloading streamlit_jupyter-0.2.1-py3-none-any.whl (13 kB)
# Downloading ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
# Using cached streamlit-1.38.0-py2.py3-none-any.whl (8.7 MB)
# Downloading fastcore-1.7.8-py3-none-any.whl (79 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading stqdm-0.0.5-py3-none-any.whl (11 kB)
# Using cached altair-5.4.1-py3-none-any.whl (658 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Using cached ipython-8.27.0-py3-none-any.whl (818 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading jupyterlab_widgets-1.1.10-py3-none-any.whl (238 kB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached tornado-6.4.1-cp38-abi3-win_amd64.whl (438 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached watchdog-4.0.2-py3-none-win_amd64.whl (82 kB)
# Downloading widgetsnbextension-3.6.9-py2.py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 11.7 MB/s eta 0:00:00
# Downloading notebook-7.2.2-py3-none-any.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ----------------------------- ---------- 3.7/5.0 MB 16.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.0/5.0 MB 16.1 MB/s eta 0:00:00
# Using cached jupyterlab-4.2.5-py3-none-any.whl (11.6 MB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Using cached bleach-6.1.0-py3-none-any.whl (162 kB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Using cached debugpy-1.8.5-cp312-cp312-win_amd64.whl (4.6 MB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Using cached jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server-2.14.2-py3-none-any.whl (383 kB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached mistune-3.0.2-py3-none-any.whl (47 kB)
# Using cached narwhals-1.8.1-py3-none-any.whl (166 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Using cached pyzmq-26.2.0-cp312-cp312-win_amd64.whl (637 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached tinycss2-1.3.0-py3-none-any.whl (22 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Using cached babel-2.16.0-py3-none-any.whl (9.6 MB)
# Using cached executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Using cached fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Using cached json5-0.9.25-py3-none-any.whl (30 kB)
# Using cached jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Using cached pywinpty-2.0.13-cp312-none-win_amd64.whl (1.4 MB)
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached webcolors-24.8.0-py3-none-any.whl (15 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached types_python_dateutil-2.9.0.20240906-py3-none-any.whl (9.7 kB)
# Installing collected packages: pure-eval, ipython-genutils, fastjsonschema, webcolors, watchdog, uri-template, types-python-dateutil, traitlets, tornado, tinycss2, send2trash, rfc3986-validator, rfc3339-validator, pyzmq, pywinpty, python-json-logger, parso, pandocfilters, narwhals, mistune, jupyterlab-widgets, jupyterlab-pygments, json5, fqdn, fastcore, executing, debugpy, blinker, bleach, babel, async-lru, asttokens, terminado, stack-data, pydeck, matplotlib-inline, jupyter-core, jedi, comm, arrow, argon2-cffi-bindings, jupyter-server-terminals, jupyter-client, isoduration, ipython, argon2-cffi, nbformat, ipykernel, altair, streamlit, nbclient, jupyter-events, jupyter-console, stqdm, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, widgetsnbextension, ipywidgets, jupyter, streamlit_jupyter
# Successfully installed altair-5.4.1 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 asttokens-2.4.1 async-lru-2.0.4 babel-2.16.0 bleach-6.1.0 blinker-1.8.2 comm-0.2.2 debugpy-1.8.5 executing-2.1.0 fastcore-1.7.8 fastjsonschema-2.20.0 fqdn-1.5.1 ipykernel-6.29.5 ipython-8.27.0 ipython-genutils-0.2.0 ipywidgets-7.7.2 isoduration-20.11.0 jedi-0.19.1 json5-0.9.25 jupyter-1.1.1 jupyter-client-8.6.3 jupyter-console-6.6.3 jupyter-core-5.7.2 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.2.5 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-1.1.10 matplotlib-inline-0.1.7 mistune-3.0.2 narwhals-1.8.1 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 notebook-7.2.2 notebook-shim-0.2.4 pandocfilters-1.5.1 parso-0.8.4 pure-eval-0.2.3 pydeck-0.9.1 python-json-logger-2.0.7 pywinpty-2.0.13 pyzmq-26.2.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 stack-data-0.6.3 stqdm-0.0.5 streamlit-1.38.0 streamlit_jupyter-0.2.1 terminado-0.18.1 tinycss2-1.3.0 tornado-6.4.1 traitlets-5.14.3 types-python-dateutil-2.9.0.20240906 uri-template-1.3.0 watchdog-4.0.2 webcolors-24.8.0 widgetsnbextension-3.6.9
#   WARNING: The script watchmedo.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script send2trash.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyjson5.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts py2pyi.exe and replace_wildcards.exe are installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script debugpy.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybabel.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-migrate.exe, jupyter-troubleshoot.exe and jupyter.exe are installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-kernel.exe, jupyter-kernelspec.exe and jupyter-run.exe are installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ipython.exe and ipython3.exe are installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-trust.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script streamlit.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-execute.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-events.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-console.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-dejavu.exe and jupyter-nbconvert.exe are installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-server.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jlpm.exe, jupyter-lab.exe, jupyter-labextension.exe and jupyter-labhub.exe are installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-notebook.exe is installed in 'C:\Users\61092657\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import streamlit as st
import plotly.express as px
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import io
import os

import streamlit as st

from streamlit_jupyter import StreamlitPatcher, tqdm

StreamlitPatcher().jupyter()

import csv
df = pd.read_json(os.path.join(os.getcwd(),'result.json'))
df['recording_date'] = pd.to_datetime(df['recording_date']).dt.date

df_grouped = df.groupby(['recording_date', 'customer_sentiment']).size().unstack(fill_value=0).reset_index()
df_grouped['total_calls'] = df_grouped[['positive', 'neutral', 'negative','unknown']].sum(axis=1)

df_melted = df_grouped.melt(id_vars=['recording_date', 'total_calls'], 
                            value_vars=['positive', 'neutral', 'negative','unknown'], 
                            var_name='Sentiment', value_name='Count')


fig = px.bar(df_melted, x='recording_date', y='Count', color='Sentiment',
             barmode='group', title='Customer Sentiment Analysis by Day',
             labels={'recording_date': 'Date', },
             text='Count')

for date, total in zip(df_grouped['recording_date'], df_grouped['total_calls']):
    fig.add_annotation(x=date, y=max(df_melted['Count']), 
                       text=f"Total: {total}", showarrow=False, 
                       yshift=10, font=dict(size=12, color="black"))


st.title("Customer Sentiment Dashboard")
st.plotly_chart(fig)
